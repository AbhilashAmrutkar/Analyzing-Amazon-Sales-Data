# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import data
df = pd.read_csv('C:\ABHILASH\Data Science\Project\Project 2\Amazon Sales Records.csv')

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
# dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
#column details
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
# missing values
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %% [markdown]
# # Observation
# No missing values

# %%
# Statistical calculations of numerical data
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
# correlation of numerical data
df.corr()
# Out:
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID       1.000000   -0.222907   -0.190941  -0.213201      -0.314688
# Units Sold    -0.222907    1.000000   -0.070486  -0.092232       0.447784
# Unit Price    -0.190941   -0.070486    1.000000   0.987270       0.752360
# Unit Cost     -0.213201   -0.092232    0.987270   1.000000       0.715623
# Total Revenue -0.314688    0.447784    0.752360   0.715623       1.000000
# Total Cost    -0.328944    0.374746    0.787905   0.774895       0.983928
# Total Profit  -0.234638    0.564550    0.557365   0.467214       0.897327
#
#                Total Cost  Total Profit
# Order ID        -0.328944     -0.234638
# Units Sold       0.374746      0.564550
# Unit Price       0.787905      0.557365
# Unit Cost        0.774895      0.467214
# Total Revenue    0.983928      0.897327
# Total Cost       1.000000      0.804091
# Total Profit     0.804091      1.000000

# %%
# variance of numerical data
df.var()
# Out:
# C:\Users\abhil\AppData\Local\Temp\ipykernel_19784\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Order ID         6.792031e+16
# Units Sold       7.809144e+06
# Unit Price       5.550370e+04
# Unit Cost        3.542232e+04
# Total Revenue    2.131684e+12
# Total Cost       1.174922e+12
# Total Profit     1.923155e+11
# dtype: float64

# %%
# covariance of numerical data
df.cov()
# Out:
#                    Order ID    Units Sold    Unit Price     Unit Cost  \
# Order ID       6.792031e+16 -1.623398e+11 -1.172359e+10 -1.045747e+10
# Units Sold    -1.623398e+11  7.809144e+06 -4.640481e+04 -4.850918e+04
# Unit Price    -1.172359e+10 -4.640481e+04  5.550370e+04  4.377593e+04
# Unit Cost     -1.045747e+10 -4.850918e+04  4.377593e+04  3.542232e+04
# Total Revenue -1.197405e+14  1.826973e+09  2.587902e+08  1.966455e+08
# Total Cost    -9.292378e+13  1.135124e+09  2.012054e+08  1.580833e+08
# Total Profit  -2.681668e+13  6.918495e+08  5.758482e+07  3.856216e+07
#
#                Total Revenue    Total Cost  Total Profit
# Order ID       -1.197405e+14 -9.292378e+13 -2.681668e+13
# Units Sold      1.826973e+09  1.135124e+09  6.918495e+08
# Unit Price      2.587902e+08  2.012054e+08  5.758482e+07
# Unit Cost       1.966455e+08  1.580833e+08  3.856216e+07
# Total Revenue   2.131684e+12  1.557145e+12  5.745386e+11
# Total Cost      1.557145e+12  1.174922e+12  3.822231e+11
# ...

# %%
# Outliers
plt.figure(figsize=(5,5))
sns.boxplot(data= df['Units Sold'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Observations
#  No outliers for column Units sold

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data= df['Unit Price'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Observations
# No outliers for column Unit Price

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data= df['Unit Cost'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Obervations
# No outliers for column Unit Cost.

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data= df['Total Revenue'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Observations
# outliers for column Total Revenue

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data= df['Total Cost'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Observations
# Outliers for column Total Cost

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data= df['Total Profit'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Observations
# Outliers for column Total Profit

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H  05-28-2010  669165933   6/27/2010        9925
# 1        Online              C  08-22-2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C  06-20-2014  514321792  07-05-2014        8102
# 4       Offline              L  02-01-2013  115456712  02-06-2013        5062
#
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H 2010-05-28  669165933 2010-06-27        9925
# 1        Online              C 2012-08-22  963881480 2012-09-15        2804
# 2       Offline              L 2014-05-02  341417157 2014-05-08        1779
# 3        Online              C 2014-06-20  514321792 2014-07-05        8102
# 4       Offline              L 2013-02-01  115456712 2013-02-06        5062
#
# ...

# %%
# pairplot
sns.pairplot(df)

# %%
# heatmap
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Observation
# There is positive correlation between Total Profit to Total cost, Total Revenue, Unit Price, Unit cost & Unit sold.

# %%
df.to_csv('C:\ABHILASH\Data Science\Project\Project 2\Amazon Sales Records R1.csv')

# %%
df1 = pd.read_csv('C:\ABHILASH\Data Science\Project\Project 2\Amazon Sales Records R1.csv')

# %%
df1.drop(labels = 'Unnamed: 0', axis=1, inplace= True)

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
# Sales by year
sales_by_Order_Date = df1.groupby("Order Date")["Total Revenue"].sum()

# %%
sales_by_Order_Date
# Out:
# Order Date
# 2010-02-02     247956.32
# 2010-02-06    3162704.80
# 2010-05-07      54319.26
# 2010-05-28    2533654.00
# 2010-06-30    1082418.40
#                  ...
# 2017-02-25    1117953.66
# 2017-03-11     246415.95
# 2017-05-08     523807.57
# 2017-05-20    1780539.20
# 2017-05-22     793518.00
# Name: Total Revenue, Length: 100, dtype: float64

# %%
# plot the data
plt.plot(sales_by_Order_Date)
plt.xlabel("Order Date")
plt.ylabel("Total Revenue")
plt.title("Sales Trend Over Time")
plt.show()

# %%
# convert the "Order date" column to a Pandas datetime object
df1["Order Date"] = pd.to_datetime(df1["Order Date"])

# %%
# extract the day, month, and year from the "order date" column
df1["o_day"] = df1["Order Date"].dt.day
df1["o_month"] = df1["Order Date"].dt.month
df1["o_year"] = df1["Order Date"].dt.year

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
# Sales by month
sales_by_month = df1.groupby("o_month")["Total Revenue"].sum()

# %%
# plot the data
plt.plot(sales_by_month)
plt.xlabel("o_month")
plt.ylabel("Total Revenue")
plt.title("Sales Trend Over Time")
plt.show()

# %%
# Sales by year
sales_by_month = df1.groupby("o_year")["Total Revenue"].sum()

# %%
# plot the data
plt.plot(sales_by_month)
plt.xlabel("o_year")
plt.ylabel("Total Revenue")
plt.title("Sales Trend Over Time")
plt.show()

# %%
# group the data by year and month and sum the sales for each year/month combination
sales_by_year_month = df1.groupby(["o_year", "o_month"])["Total Revenue"].sum()

# %%
sales_by_year_month
# Out:
# o_year  o_month
# 2010    2          3410661.12
#         5          2587973.26
#         6          1082418.40
#         10         6064933.75
#         11         3458252.00
#         12         2581786.39
# 2011    1          1042225.35
#         2           387002.20
#         4          2798046.49
#         5           272410.45
#         6            19103.44
#         7            97040.64
#         9           574951.92
#         11         5938385.58
# 2012    1          1012884.00
#         2          6707849.42
#         3           994765.42
#         4          4556012.38
#         5          3782781.82
#         6          2132075.27
#         7          4445093.92
#         8           576782.80
#         9          4648152.72
#         10         3042246.77
# 2013    2          3296425.02
#         3           835759.10
#         4          3262562.10
#         6          1352867.40
#         7          8545511.20
#         8            89623.98
# ...

# %%
df1.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H 2010-05-28  669165933  2010-06-27        9925
# 1        Online              C 2012-08-22  963881480  2012-09-15        2804
# 2       Offline              L 2014-05-02  341417157  2014-05-08        1779
# 3        Online              C 2014-06-20  514321792  2014-07-05        8102
# 4       Offline              L 2013-02-01  115456712  2013-02-06        5062
#
# ...

# %%
# most frquent Item types
df1['Item Type'].mode()
# Out:
# 0      Clothes
# 1    Cosmetics
# Name: Item Type, dtype: object

# %%
# most frequent region
df1['Region'].mode()
# Out:
# 0    Sub-Saharan Africa
# Name: Region, dtype: object

# %%
# most freuent order year
df1['o_year'].mode()
# Out:
# 0    2012
# Name: o_year, dtype: int64

# %%
# most frequient order month
df1['o_month'].mode()
# Out:
# 0    2
# Name: o_month, dtype: int64

# %%
# Medain for units sold
df1['Units Sold'].median()
# Out:
# 5382.5

# %%
# Medain for unit price
df1['Unit Price'].median()
# Out:
# 179.88

# %%
# Medain for unit cost
df1['Unit Cost'].median()
# Out:
# 107.275

# %%
df1.to_csv('C:\ABHILASH\Data Science\Project\Project 2\Amazon Sales Records R2.csv')

# %%
sales_by_year_month.to_csv('C:\ABHILASH\Data Science\Project\Project 2\Sales by year month.csv')
